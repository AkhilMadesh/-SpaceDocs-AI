# %% [markdown]
# # SpaceDocs AI — Experimentation Notebook
#
# Use this notebook to prototype chunking strategies, test embedding models,
# or inspect retrieval results before committing changes to `backend/`.
#
# Run `pip install -r ../requirements.txt` first if dependencies are missing.

# %%
import sys
sys.path.insert(0, "..")

from backend.ingestion.pdf_loader import parse_pdf
from backend.chunking.chunker import chunk_document
from backend.embeddings.embedder import embed_texts

# Example: parse a sample PDF and inspect the first few chunks
# parsed = parse_pdf("../data/uploads/sample.pdf")
# chunks = chunk_document(parsed, document_id="sample_001")
# for c in chunks[:3]:
#     print(c.text[:200], "\n---")
